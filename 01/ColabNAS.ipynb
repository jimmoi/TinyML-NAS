# %% [markdown]
# #Before starting:
# * This notebook is meant to run on Google Colaboratory;
# * It requires you to download a third party software, otherwise it will not run. (I know it's tedious but I don't own the program and so I can't share it with you);
# * I suggest to use an environment with a GPU.

# %% [markdown]
# ##Preliminaries

# %% [markdown]
# ###Install 'tensorflow-model-optimization' for Quantization Aware Training (QAT)

# %%
# !pip install -q tensorflow-model-optimization
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 16.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 59.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# shap 0.50.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.35.1 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.

# %% [markdown]
# ###Get 'stm32tflm' software

# %% [markdown]
# * Download 'X-CUBE-AI-Linux' package from https://www.st.com/en/embedded-software/x-cube-ai.html;
# * Extract the 'stm32tflm' executable from the downloaded package;
# * Put it in the folder you're working (usually '/content/' for Google Colaboratory).

# %% [markdown]
# Enable the execution of the 'stm32tflm' program

# %%
# !git clone https://github.com/AndreaMattiaGaravagno/ColabNAS
# Out:
# Cloning into 'ColabNAS'...
# remote: Enumerating objects: 56, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 56 (delta 23), reused 11 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (56/56), 463.65 KiB | 4.29 MiB/s, done.
# Resolving deltas: 100% (23/23), done.

# %%
# !chmod +x /content/ColabNAS/stm32tflm

# %%
mv /content/ColabNAS/stm32tflm /content/

# %%
# !pip install --upgrade numpy==2.0.0
# Out:
# Requirement already satisfied: numpy==2.0.0 in /usr/local/lib/python3.12/dist-packages (2.0.0)

# %% [markdown]
# ##ColabNAS code

# %%
from tensorflow_model_optimization.python.core.keras.compat import keras
from pathlib import Path
import tensorflow as tf
import numpy as np
import subprocess
import datetime
import shutil
import glob
import re
import os

class ColabNAS :
    architecture_name = 'resulting_architecture'
    def __init__(self, max_RAM, max_Flash, max_MACC, path_to_training_set, val_split, cache=False, input_shape=(50,50,3), save_path='.', path_to_stm32tflm='/content/stm32tflm') :
        self.learning_rate = 1e-3
        self.batch_size = 128
        self.epochs = 100 #minimum 2

        self.max_MACC = max_MACC
        self.max_Flash = max_Flash
        self.max_RAM = max_RAM
        self.path_to_training_set = path_to_training_set
        self.num_classes = len(next(os.walk(path_to_training_set))[1])
        self.val_split = val_split
        self.cache = cache
        self.input_shape = input_shape
        self.save_path = Path(save_path)

        self.path_to_trained_models = self.save_path / "trained_models"
        self.path_to_trained_models.mkdir(parents=True)

        self.path_to_stm32tflm = Path(path_to_stm32tflm)

        self.load_training_set()

    # k number of kernels of the first convolutional layer
    # c number of cells added upon the first convolutional layer
    # pre-processing pipeline not included in MACC computation
    def Model(self, k, c) :
        kernel_size = (3,3)
        pool_size = (2,2)
        pool_strides = (2,2)

        number_of_cells_limited = False
        number_of_mac = 0

        inputs = keras.Input(shape=self.input_shape)

        #convolutional base
        n = int(k)
        multiplier = 2

        #first convolutional layer
        c_in = self.input_shape[2]
        x = keras.layers.Conv2D(n, kernel_size, padding='same')(inputs)
        x = keras.layers.BatchNormalization()(x)
        x = keras.layers.ReLU()(x)

        number_of_mac = number_of_mac + (c_in * kernel_size[0] * kernel_size[1] * x.shape[1] * x.shape[2] * x.shape[3])

        #adding cells
        for i in range(1, c + 1) :
            if x.shape[1] <= 1 or x.shape[2] <= 1 :
                number_of_cells_limited = True
                break;
            n = int(np.ceil(n * multiplier))
            multiplier = multiplier - 2**-i
            x = keras.layers.MaxPooling2D(pool_size=pool_size, strides=pool_strides, padding='valid')(x)
            c_in = x.shape[3]
            x = keras.layers.Conv2D(n, kernel_size, padding='same')(x)
            x = keras.layers.BatchNormalization()(x)
            x = keras.layers.ReLU()(x)
            number_of_mac = number_of_mac + (c_in * kernel_size[0] * kernel_size[1] * x.shape[1] * x.shape[2] * x.shape[3])

        #classifier
        x = keras.layers.GlobalAveragePooling2D()(x)
        input_shape = x.shape[1]
        x = keras.layers.Dense(n)(x)
        x = keras.layers.BatchNormalization()(x)
        x = keras.layers.ReLU()(x)
        number_of_mac = number_of_mac + (input_shape * x.shape[1])
        x = keras.layers.Dense(self.num_classes)(x)
        x = keras.layers.BatchNormalization()(x)
        outputs = keras.layers.Softmax()(x)
        number_of_mac = number_of_mac + (x.shape[1] * outputs.shape[1])

        model = keras.Model(inputs=inputs, outputs=outputs)

        opt = tf.keras.optimizers.Adam(learning_rate=self.learning_rate)
        model.compile(optimizer=opt,
                loss='categorical_crossentropy',
                metrics=['accuracy'])

        model.summary()

        return model, number_of_mac, number_of_cells_limited

    def load_training_set(self):
        if 3 == self.input_shape[2] :
            color_mode = 'rgb'
        elif 1 == self.input_shape[2] :
            color_mode = 'grayscale'

        train_ds = tf.keras.utils.image_dataset_from_directory(
            directory= self.path_to_training_set,
            labels='inferred',
            label_mode='categorical',
            color_mode=color_mode,
            batch_size=self.batch_size,
            image_size=self.input_shape[0:2],
            shuffle=True,
            seed=11,
            validation_split=self.val_split,
            subset='training'
        )

        validation_ds = tf.keras.utils.image_dataset_from_directory(
            directory= self.path_to_training_set,
            labels='inferred',
            label_mode='categorical',
            color_mode=color_mode,
            batch_size=self.batch_size,
            image_size=self.input_shape[0:2],
            shuffle=True,
            seed=11,
            validation_split=self.val_split,
            subset='validation'
        )

        data_augmentation = tf.keras.Sequential([
            tf.keras.layers.RandomFlip("horizontal"),
            tf.keras.layers.RandomRotation(0.2, fill_mode='constant', interpolation='bilinear'),
            #tf.keras.layers.Rescaling(1./255)
            ])

        if self.cache :
            self.train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y), num_parallel_calls=tf.data.AUTOTUNE).cache().prefetch(buffer_size=tf.data.AUTOTUNE)
            self.validation_ds = validation_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
        else :
            self.train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y), num_parallel_calls=tf.data.AUTOTUNE).prefetch(buffer_size=tf.data.AUTOTUNE)
            self.validation_ds = validation_ds.prefetch(buffer_size=tf.data.AUTOTUNE)

    def quantize_model_uint8(self) :
        def representative_dataset():
            for data in self.train_ds.rebatch(1).take(150) :
                yield [tf.dtypes.cast(data[0], tf.float32)]

        model = tf.keras.models.load_model(self.path_to_trained_models / f"{self.model_name}.h5")
        converter = tf.lite.TFLiteConverter.from_keras_model(model)
        converter.optimizations = [tf.lite.Optimize.DEFAULT]
        converter.representative_dataset = representative_dataset
        converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
        converter.inference_input_type = tf.uint8
        converter.inference_output_type = tf.uint8
        tflite_quant_model = converter.convert()

        with open(self.path_to_trained_models / f"{self.model_name}.tflite", 'wb') as f:
            f.write(tflite_quant_model)

        (self.path_to_trained_models / f"{self.model_name}.h5").unlink()

    def evaluate_flash_and_peak_RAM_occupancy(self) :
        #quantize model to evaluate its peak RAM occupancy and its Flash occupancy
        self.quantize_model_uint8()

        #evaluate its peak RAM occupancy and its Flash occupancy using STMicroelectronics' X-CUBE-AI
        proc = subprocess.Popen([self.path_to_stm32tflm, self.path_to_trained_models / f"{self.model_name}.tflite"], stdout=subprocess.PIPE)
        try:
            outs, errs = proc.communicate(timeout=15)
            Flash, RAM = re.findall(r'\d+', str(outs))
        except subprocess.TimeoutExpired:
            proc.kill()
            outs, errs = proc.communicate()
            print("stm32tflm error")
            exit()

        return int(Flash), int(RAM)

    def evaluate_model_process(self, k, c) :
        if k > 0 :
            self.model_name = f"k_{k}_c_{c}"
            print(f"\n{self.model_name}\n")
            checkpoint = tf.keras.callbacks.ModelCheckpoint(
                str(self.path_to_trained_models / f"{self.model_name}.h5"), monitor='val_accuracy',
                verbose=1, save_best_only=True, save_weights_only=False, mode='auto')
            model, MACC, number_of_cells_limited = self.Model(k, c)
            #One epoch of training must be done before quantization, which is needed to evaluate RAM and Flash occupancy
            model.fit(self.train_ds, epochs=1, validation_data=self.validation_ds, validation_freq=1)
            model.save(self.path_to_trained_models / f"{self.model_name}.h5")
            Flash, RAM = self.evaluate_flash_and_peak_RAM_occupancy()
            print(f"\nRAM: {RAM},\t Flash: {Flash},\t MACC: {MACC}\n")
            if MACC <= self.max_MACC and Flash <= self.max_Flash and RAM <= self.max_RAM and not number_of_cells_limited :
                hist = model.fit(self.train_ds, epochs=self.epochs - 1, validation_data=self.validation_ds, validation_freq=1, callbacks=[checkpoint])
                self.quantize_model_uint8()
            return {'k': k,
                    'c': c if not number_of_cells_limited else "Not feasible",
                    'RAM': RAM if RAM <= self.max_RAM else "Outside the upper bound",
                    'Flash': Flash if Flash <= self.max_Flash else "Outside the upper bound",
                    'MACC': MACC if MACC <= self.max_MACC else "Outside the upper bound",
                    'max_val_acc':
                    np.around(np.amax(hist.history['val_accuracy']), decimals=3)
                    if 'hist' in locals() else -3}
        else :
            return{'k': 'unfeasible', 'c': c, 'max_val_acc': -3}

    def explore_num_cells(self, k) :
        previous_architecture = {'k': -1, 'c': -1, 'max_val_acc': -2}
        current_architecture = {'k': -1, 'c': -1, 'max_val_acc': -1}
        c = -1
        k = int(k)

        while(current_architecture['max_val_acc'] > previous_architecture['max_val_acc']) :
            previous_architecture = current_architecture
            c = c + 1
            self.model_counter = self.model_counter + 1
            current_architecture = self.evaluate_model_process(k, c)
            print(f"\n\n\n{current_architecture}\n\n\n")
        return previous_architecture

    def search(self) :
        self.model_counter = 0
        epsilon = 0.005
        k0 = 4

        start = datetime.datetime.now()

        k = k0
        previous_architecture = self.explore_num_cells(k)
        k = 2 * k
        current_architecture = self.explore_num_cells(k)

        if (current_architecture['max_val_acc'] > previous_architecture['max_val_acc']) :
            previous_architecture = current_architecture
            k = 2 * k
            current_architecture = self.explore_num_cells(k)
            while(current_architecture['max_val_acc'] > previous_architecture['max_val_acc'] + epsilon) :
                previous_architecture = current_architecture
                k = 2 * k
                current_architecture = self.explore_num_cells(k)
        else :
            k = k0 / 2
            current_architecture = self.explore_num_cells(k)
            while(current_architecture['max_val_acc'] >= previous_architecture['max_val_acc']) :
                previous_architecture = current_architecture
                k = k / 2
                current_architecture = self.explore_num_cells(k)

        resulting_architecture = previous_architecture

        end = datetime.datetime.now()

        if (resulting_architecture['max_val_acc'] > 0) :
            resulting_architecture_name = f"k_{resulting_architecture['k']}_c_{resulting_architecture['c']}.tflite"
            self.path_to_resulting_architecture = self.save_path / f"resulting_architecture_{resulting_architecture_name}"
            (self.path_to_trained_models / f"{resulting_architecture_name}").rename(self.path_to_resulting_architecture)
            shutil.rmtree(self.path_to_trained_models)
            print(f"\nResulting architecture: {resulting_architecture}\n")
        else :
            print(f"\nNo feasible architecture found\n")
        print(f"Elapsed time (search): {end-start}\n")

        return self.path_to_resulting_architecture

# %% [markdown]
# ##Try ColabNAS!

# %% [markdown]
# ###download a small dataset

# %%
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file('flower_photos.tar', origin=dataset_url, extract=True)
data_dir = Path(data_dir).with_suffix('')
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# 228813984/228813984 [==============================] - 6s 0us/step

# %%
data_dir
# Out:
# PosixPath('/root/.keras/datasets/flower_photos')

# %% [markdown]
# ###Run HW-NAS
# target: STM32L412KBU3 (273 CoreMark, 40 kiB RAM, 128 kiB Flash)

# %%
import numpy as np
import tensorflow as tf

input_shape = (50,50,3)

#target: STM32L412KBU3
#273 CoreMark, 40 kiB RAM, 128 kiB Flash
peak_RAM_upper_bound = 40960
Flash_upper_bound = 131072
MACC_upper_bound = 2730000 #CoreMark * 1e4

#Each dataset must comply with the following structure
#main_directory/
#...class_a/
#......a_image_1.jpg
#......a_image_2.jpg
#...class_b/
#......b_image_1.jpg
#......b_image_2.jpg
path_to_training_set = data_dir
val_split = 0.3

#whether or not to cache datasets in memory
#if the dataset cannot fit in the main memory, the application will crash
cache = True

#where to save results
save_path = '/content/'

#to show the GPU used
# !nvidia-smi

colabNAS = ColabNAS(peak_RAM_upper_bound, Flash_upper_bound, MACC_upper_bound, path_to_training_set, val_split, cache, input_shape, save_path=save_path)

#search
path_to_tflite_model = colabNAS.search()
# Out:
# Sun Jan  4 15:08:57 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   55C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Found 3670 files belonging to 5 classes.
# Using 2569 files for training.
# Found 3670 files belonging to 5 classes.
# Using 1101 files for validation.
#
# k_4_c_0
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 50, 50, 3)]       0
#
#  conv2d (Conv2D)             (None, 50, 50, 4)         112
#
#  batch_normalization (Batch  (None, 50, 50, 4)         16
#  Normalization)
#
#  re_lu (ReLU)                (None, 50, 50, 4)         0
#
#  global_average_pooling2d (  (None, 4)                 0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 4)                 20
#
#  batch_normalization_1 (Bat  (None, 4)                 16
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 4)                 0
#
#  dense_1 (Dense)             (None, 5)                 25
#
#  batch_normalization_2 (Bat  (None, 5)                 20
#  chNormalization)
#
#  softmax (Softmax)           (None, 5)                 0
#
# =================================================================
# Total params: 209 (836.00 Byte)
# Trainable params: 183 (732.00 Byte)
# Non-trainable params: 26 (104.00 Byte)
# _________________________________________________________________
# 21/21 [==============================] - 10s 146ms/step - loss: 1.9597 - accuracy: 0.1938 - val_loss: 1.5998 - val_accuracy: 0.2679
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/engine/training.py:3098: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native TF-Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py:854: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# RAM: 19968,	 Flash: 3832,	 MACC: 270041
#
# Epoch 1/99
# 15/21 [====================>.........] - ETA: 0s - loss: 1.8880 - accuracy: 0.1990
# Epoch 1: val_accuracy improved from -inf to 0.26975, saving model to /content/trained_models/k_4_c_0.h5
# 21/21 [==============================] - 0s 11ms/step - loss: 1.8815 - accuracy: 0.2024 - val_loss: 1.6012 - val_accuracy: 0.2698
# Epoch 2/99
# 14/21 [===================>..........] - ETA: 0s - loss: 1.8283 - accuracy: 0.2182
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/engine/training.py:3098: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native TF-Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_accuracy improved from 0.26975 to 0.29064, saving model to /content/trained_models/k_4_c_0.h5
# 21/21 [==============================] - 0s 12ms/step - loss: 1.8203 - accuracy: 0.2289 - val_loss: 1.6054 - val_accuracy: 0.2906
# Epoch 3/99
# 16/21 [=====================>........] - ETA: 0s - loss: 1.7625 - accuracy: 0.2559
# Epoch 3: val_accuracy improved from 0.29064 to 0.29973, saving model to /content/trained_models/k_4_c_0.h5
# 21/21 [==============================] - 0s 11ms/step - loss: 1.7620 - accuracy: 0.2581 - val_loss: 1.6069 - val_accuracy: 0.2997
# Epoch 4/99
# 15/21 [====================>.........] - ETA: 0s - loss: 1.7145 - accuracy: 0.2708
# Epoch 4: val_accuracy did not improve from 0.29973
# 21/21 [==============================] - 0s 9ms/step - loss: 1.7129 - accuracy: 0.2736 - val_loss: 1.5962 - val_accuracy: 0.2997
# Epoch 5/99
# 15/21 [====================>.........] - ETA: 0s - loss: 1.6735 - accuracy: 0.2849
# Epoch 5: val_accuracy did not improve from 0.29973
# 21/21 [==============================] - 0s 9ms/step - loss: 1.6736 - accuracy: 0.2900 - val_loss: 1.5994 - val_accuracy: 0.2870
# Epoch 6/99
# 17/21 [=======================>......] - ETA: 0s - loss: 1.6437 - accuracy: 0.3019
# Epoch 6: val_accuracy did not improve from 0.29973
# 21/21 [==============================] - 0s 9ms/step - loss: 1.6444 - accuracy: 0.3052 - val_loss: 1.6055 - val_accuracy: 0.2852
# Epoch 7/99
# 15/21 [====================>.........] - ETA: 0s - loss: 1.6177 - accuracy: 0.3099
# Epoch 7: val_accuracy did not improve from 0.29973
# 21/21 [==============================] - 0s 9ms/step - loss: 1.6201 - accuracy: 0.3153 - val_loss: 1.6099 - val_accuracy: 0.2843
# Epoch 8/99
# 17/21 [=======================>......] - ETA: 0s - loss: 1.5978 - accuracy: 0.3254
# Epoch 8: val_accuracy did not improve from 0.29973
# 21/21 [==============================] - 0s 9ms/step - loss: 1.5990 - accuracy: 0.3285 - val_loss: 1.6118 - val_accuracy: 0.2861
# Epoch 9/99
# 16/21 [=====================>........] - ETA: 0s - loss: 1.5745 - accuracy: 0.3379
# Epoch 9: val_accuracy did not improve from 0.29973
# 21/21 [==============================] - 0s 9ms/step - loss: 1.5796 - accuracy: 0.3390 - val_loss: 1.6094 - val_accuracy: 0.2925
# Epoch 10/99
# 17/21 [=======================>......] - ETA: 0s - loss: 1.5600 - accuracy: 0.3460
# Epoch 10: val_accuracy improved from 0.29973 to 0.30336, saving model to /content/trained_models/k_4_c_0.h5
# 21/21 [==============================] - 0s 11ms/step - loss: 1.5610 - accuracy: 0.3476 - val_loss: 1.6009 - val_accuracy: 0.3034
# Epoch 11/99
# 17/21 [=======================>......] - ETA: 0s - loss: 1.5433 - accuracy: 0.3497
# Epoch 11: val_accuracy improved from 0.30336 to 0.30609, saving model to /content/trained_models/k_4_c_0.h5
# 21/21 [==============================] - 0s 11ms/step - loss: 1.5441 - accuracy: 0.3523 - val_loss: 1.5923 - val_accuracy: 0.3061
# Epoch 12/99
# 16/21 [=====================>........] - ETA: 0s - loss: 1.5237 - accuracy: 0.3608
# Epoch 12: val_accuracy improved from 0.30609 to 0.31244, saving model to /content/trained_models/k_4_c_0.h5
# 21/21 [==============================] - 0s 11ms/step - loss: 1.5284 - accuracy: 0.3612 - val_loss: 1.5830 - val_accuracy: 0.3124
# Epoch 13/99
# 17/21 [=======================>......] - ETA: 0s - loss: 1.5135 - accuracy: 0.3709
# Epoch 13: val_accuracy did not improve from 0.31244
# 21/21 [==============================] - 0s 9ms/step - loss: 1.5142 - accuracy: 0.3729 - val_loss: 1.5704 - val_accuracy: 0.3124
# Epoch 14/99
# 17/21 [=======================>......] - ETA: 0s - loss: 1.5003 - accuracy: 0.3736
# Epoch 14: val_accuracy improved from 0.31244 to 0.31335, saving model to /content/trained_models/k_4_c_0.h5
# 21/21 [==============================] - 0s 11ms/step - loss: 1.5010 - accuracy: 0.3756 - val_loss: 1.5579 - val_accuracy: 0.3134
# Epoch 15/99
# 17/21 [=======================>......] - ETA: 0s - loss: 1.4882 - accuracy: 0.3805
# Epoch 15: val_accuracy improved from 0.31335 to 0.31426, saving model to /content/trained_models/k_4_c_0.h5
# 21/21 [==============================] - 0s 10ms/step - loss: 1.4887 - accuracy: 0.3826 - val_loss: 1.5424 - val_accuracy: 0.3143
# Epoch 16/99
# 17/21 [=======================>......] - ETA: 0s - loss: 1.4767 - accuracy: 0.3869
# Epoch 16: val_accuracy improved from 0.31426 to 0.31789, saving model to /content/trained_models/k_4_c_0.h5
# 21/21 [==============================] - 0s 11ms/step - loss: 1.4771 - accuracy: 0.3889 - val_loss: 1.5281 - val_accuracy: 0.3179
# Epoch 17/99
# 17/21 [=======================>......] - ETA: 0s - loss: 1.4654 - accuracy: 0.3902
# Epoch 17: val_accuracy improved from 0.31789 to 0.32062, saving model to /content/trained_models/k_4_c_0.h5
# 21/21 [==============================] - 0s 11ms/step - loss: 1.4657 - accuracy: 0.3931 - val_loss: 1.5175 - val_accuracy: 0.3206
# Epoch 18/99
# 17/21 [=======================>......] - ETA: 0s - loss: 1.4537 - accuracy: 0.3938
# Epoch 18: val_accuracy improved from 0.32062 to 0.32425, saving model to /content/trained_models/k_4_c_0.h5
# 21/21 [==============================] - 0s 11ms/step - loss: 1.4538 - accuracy: 0.3974 - val_loss: 1.5134 - val_accuracy: 0.3243
# Epoch 19/99
# 16/21 [=====================>........] - ETA: 0s - loss: 1.4369 - accuracy: 0.3975
# Epoch 19: val_accuracy improved from 0.32425 to 0.32698, saving model to /content/trained_models/k_4_c_0.h5
# 21/21 [==============================] - 0s 11ms/step - loss: 1.4415 - accuracy: 0.3974 - val_loss: 1.5098 - val_accuracy: 0.3270
# Epoch 20/99
# 17/21 [=======================>......] - ETA: 0s - loss: 1.4297 - accuracy: 0.4012
# Epoch 20: val_accuracy improved from 0.32698 to 0.33787, saving model to /content/trained_models/k_4_c_0.h5
# 21/21 [==============================] - 0s 12ms/step - loss: 1.4299 - accuracy: 0.3998 - val_loss: 1.4912 - val_accuracy: 0.3379
# Epoch 21/99
# 15/21 [====================>.........] - ETA: 0s - loss: 1.4129 - accuracy: 0.4052
# Epoch 21: val_accuracy improved from 0.33787 to 0.35059, saving model to /content/trained_models/k_4_c_0.h5
# 21/21 [==============================] - 0s 11ms/step - loss: 1.4190 - accuracy: 0.4009 - val_loss: 1.4729 - val_accuracy: 0.3506
# Epoch 22/99
# 17/21 [=======================>......] - ETA: 0s - loss: 1.4082 - accuracy: 0.4062
# Epoch 22: val_accuracy improved from 0.35059 to 0.35150, saving model to /content/trained_models/k_4_c_0.h5
# 21/21 [==============================] - 0s 11ms/step - loss: 1.4085 - accuracy: 0.4068 - val_loss: 1.4718 - val_accuracy: 0.3515
# Epoch 23/99
# 16/21 [=====================>........] - ETA: 0s - loss: 1.3935 - accuracy: 0.4077
# Epoch 23: val_accuracy improved from 0.35150 to 0.35604, saving model to /content/trained_models/k_4_c_0.h5
# 21/21 [==============================] - 0s 11ms/step - loss: 1.3986 - accuracy: 0.4083 - val_loss: 1.4560 - val_accuracy: 0.3560
# Epoch 24/99
# 17/21 [=======================>......] - ETA: 0s - loss: 1.3883 - accuracy: 0.4076
# Epoch 24: val_accuracy improved from 0.35604 to 0.35876, saving model to /content/trained_models/k_4_c_0.h5
# 21/21 [==============================] - 0s 11ms/step - loss: 1.3891 - accuracy: 0.4083 - val_loss: 1.4495 - val_accuracy: 0.3588
# Epoch 25/99
# 17/21 [=======================>......] - ETA: 0s - loss: 1.
# 21/21 [==============================] - 0s 9ms/step - loss: 1.1677 - accuracy: 0.5072 - val_loss: 1.4250 - val_accuracy: 0.4441
# Epoch 77/99
# 15/21 [====================>.........] - ETA: 0s - loss: 1.1545 - accuracy: 0.5182
# Epoch 77: val_accuracy improved from 0.44777 to 0.45322, saving model to /content/trained_models/k_4_c_0.h5
# 21/21 [==============================] - 0s 11ms/step - loss: 1.1662 - accuracy: 0.5088 - val_loss: 1.3989 - val_accuracy: 0.4532
# Epoch 78/99
# 16/21 [=====================>........] - ETA: 0s - loss: 1.1566 - accuracy: 0.5190
# Epoch 78: val_accuracy did not improve from 0.45322
# 21/21 [==============================] - 0s 9ms/step - loss: 1.1642 - accuracy: 0.5111 - val_loss: 1.4263 - val_accuracy: 0.4496
# Epoch 79/99
# 15/21 [====================>.........] - ETA: 0s - loss: 1.1502 - accuracy: 0.5214
# Epoch 79: val_accuracy did not improve from 0.45322
# 21/21 [==============================] - 0s 9ms/step - loss: 1.1627 - accuracy: 0.5099 - val_loss: 1.4133 - val_accuracy: 0.4514
# Epoch 80/99
# 17/21 [=======================>......] - ETA: 0s - loss: 1.1598 - accuracy: 0.5152
# Epoch 80: val_accuracy did not improve from 0.45322
# 21/21 [==============================] - 0s 9ms/step - loss: 1.1616 - accuracy: 0.5130 - val_loss: 1.4092 - val_accuracy: 0.4532
# Epoch 81/99
# 17/21 [=======================>......] - ETA: 0s - loss: 1.1579 - accuracy: 0.5161
# Epoch 81: val_accuracy did not improve from 0.45322
# 21/21 [==============================] - 0s 9ms/step - loss: 1.1597 - accuracy: 0.5134 - val_loss: 1.4329 - val_accuracy: 0.4514
# Epoch 82/99
# 16/21 [=====================>........] - ETA: 0s - loss: 1.1503 - accuracy: 0.5225
# Epoch 82: val_accuracy did not improve from 0.45322
# 21/21 [==============================] - 0s 9ms/step - loss: 1.1585 - accuracy: 0.5146 - val_loss: 1.4248 - val_accuracy: 0.4514
# Epoch 83/99
# 15/21 [====================>.........] - ETA: 0s - loss: 1.1443 - accuracy: 0.5234
# Epoch 83: val_accuracy improved from 0.45322 to 0.45958, saving model to /content/trained_models/k_4_c_0.h5
# 21/21 [==============================] - 0s 12ms/step - loss: 1.1572 - accuracy: 0.5142 - val_loss: 1.3963 - val_accuracy: 0.4596
# Epoch 84/99
# 21/21 [==============================] - ETA: 0s - loss: 1.1556 - accuracy: 0.5127
# Epoch 84: val_accuracy did not improve from 0.45958
# 21/21 [==============================] - 0s 10ms/step - loss: 1.1556 - accuracy: 0.5127 - val_loss: 1.4276 - val_accuracy: 0.4541
# Epoch 85/99
# 15/21 [====================>.........] - ETA: 0s - loss: 1.1410 - accuracy: 0.5214
# Epoch 85: val_accuracy did not improve from 0.45958
# 21/21 [==============================] - 0s 9ms/step - loss: 1.1541 - accuracy: 0.5138 - val_loss: 1.4323 - val_accuracy: 0.4523
# Epoch 86/99
# 17/21 [=======================>......] - ETA: 0s - loss: 1.1507 - accuracy: 0.5152
# Epoch 86: val_accuracy did not improve from 0.45958
# 21/21 [==============================] - 0s 9ms/step - loss: 1.1526 - accuracy: 0.5142 - val_loss: 1.4315 - val_accuracy: 0.4514
# Epoch 87/99
# 17/21 [=======================>......] - ETA: 0s - loss: 1.1491 - accuracy: 0.5147
# Epoch 87: val_accuracy did not improve from 0.45958
# 21/21 [==============================] - 0s 10ms/step - loss: 1.1510 - accuracy: 0.5138 - val_loss: 1.4319 - val_accuracy: 0.4505
# Epoch 88/99
# 16/21 [=====================>........] - ETA: 0s - loss: 1.1407 - accuracy: 0.5205
# Epoch 88: val_accuracy did not improve from 0.45958
# 21/21 [==============================] - 0s 11ms/step - loss: 1.1492 - accuracy: 0.5150 - val_loss: 1.4303 - val_accuracy: 0.4505
# Epoch 89/99
# 15/21 [====================>.........] - ETA: 0s - loss: 1.1335 - accuracy: 0.5219
# Epoch 89: val_accuracy did not improve from 0.45958
# 21/21 [==============================] - 0s 9ms/step - loss: 1.1472 - accuracy: 0.5142 - val_loss: 1.4926 - val_accuracy: 0.4332
# Epoch 90/99
# 17/21 [=======================>......] - ETA: 0s - loss: 1.1449 - accuracy: 0.5170
# Epoch 90: val_accuracy improved from 0.45958 to 0.46231, saving model to /content/trained_models/k_4_c_0.h5
# 21/21 [==============================] - 0s 11ms/step - loss: 1.1465 - accuracy: 0.5158 - val_loss: 1.4057 - val_accuracy: 0.4623
# Epoch 91/99
# 16/21 [=====================>........] - ETA: 0s - loss: 1.1350 - accuracy: 0.5249
# Epoch 91: val_accuracy did not improve from 0.46231
# 21/21 [==============================] - 0s 9ms/step - loss: 1.1434 - accuracy: 0.5189 - val_loss: 1.4604 - val_accuracy: 0.4450
# Epoch 92/99
# 16/21 [=====================>........] - ETA: 0s - loss: 1.1345 - accuracy: 0.5229
# Epoch 92: val_accuracy improved from 0.46231 to 0.46503, saving model to /content/trained_models/k_4_c_0.h5
# 21/21 [==============================] - 0s 11ms/step - loss: 1.1428 - accuracy: 0.5169 - val_loss: 1.4115 - val_accuracy: 0.4650
# Epoch 93/99
# 16/21 [=====================>........] - ETA: 0s - loss: 1.1326 - accuracy: 0.5254
# Epoch 93: val_accuracy improved from 0.46503 to 0.47048, saving model to /content/trained_models/k_4_c_0.h5
# 21/21 [==============================] - 0s 12ms/step - loss: 1.1411 - accuracy: 0.5177 - val_loss: 1.3687 - val_accuracy: 0.4705
# Epoch 94/99
# 16/21 [=====================>........] - ETA: 0s - loss: 1.1310 - accuracy: 0.5264
# Epoch 94: val_accuracy improved from 0.47048 to 0.47321, saving model to /content/trained_models/k_4_c_0.h5
# 21/21 [==============================] - 0s 16ms/step - loss: 1.1394 - accuracy: 0.5197 - val_loss: 1.3559 - val_accuracy: 0.4732
# Epoch 95/99
# 19/21 [==========================>...] - ETA: 0s - loss: 1.1361 - accuracy: 0.5288
# Epoch 95: val_accuracy did not improve from 0.47321
# 21/21 [==============================] - 0s 12ms/step - loss: 1.1371 - accuracy: 0.5243 - val_loss: 1.3802 - val_accuracy: 0.4696
# Epoch 96/99
# 19/21 [==========================>...] - ETA: 0s - loss: 1.1348 - accuracy: 0.5296
# Epoch 96: val_accuracy did not improve from 0.47321
# 21/21 [==============================] - 0s 13ms/step - loss: 1.1355 - accuracy: 0.5251 - val_loss: 1.4108 - val_accuracy: 0.4623
# Epoch 97/99
# 18/21 [========================>.....] - ETA: 0s - loss: 1.1330 - accuracy: 0.5260
# Epoch 97: val_accuracy did not improve from 0.47321
# 21/21 [==============================] - 0s 12ms/step - loss: 1.1337 - accuracy: 0.5259 - val_loss: 1.3962 - val_accuracy: 0.4587
# Epoch 98/99
# 19/21 [==========================>...] - ETA: 0s - loss: 1.1313 - accuracy: 0.5284
# Epoch 98: val_accuracy did not improve from 0.47321
# 21/21 [==============================] - 0s 13ms/step - loss: 1.1320 - accuracy: 0.5247 - val_loss: 1.3937 - val_accuracy: 0.4623
# Epoch 99/99
# 19/21 [==========================>...] - ETA: 0s - loss: 1.1295 - accuracy: 0.5271
# Epoch 99: val_accuracy did not improve from 0.47321
# 21/21 [==============================] - 0s 12ms/step - loss: 1.1302 - accuracy: 0.5239 - val_loss: 1.3684 - val_accuracy: 0.4696
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py:854: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# {'k': 4, 'c': 0, 'RAM': 19968, 'Flash': 3832, 'MACC': 270041, 'max_val_acc': np.float64(0.473)}
#
#
#
#
# k_4_c_1
#
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 50, 50, 3)]       0
#
#  conv2d_1 (Conv2D)           (None, 50, 50, 4)         112
#
#  batch_normalization_3 (Bat  (None, 50, 50, 4)         16
#  chNormalization)
#
#  re_lu_2 (ReLU)              (None, 50, 50, 4)         0
#
#  max_pooling2d (MaxPooling2  (None, 25, 25, 4)         0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 25, 25, 8)         296
#
#  batch_normalization_4 (Bat  (None, 25, 25, 8)         32
#  chNormalization)
#
#  re_lu_3 (ReLU)              (None, 25, 25, 8)         0
#
#  global_average_pooling2d_1  (None, 8)                 0
#   (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 8)                 72
#
#  batch_normalization_5 (Bat  (None, 8)                 32
#  chNormalization)
#
#  re_lu_4 (ReLU)              (None, 8)                 0
#
#  dense_3 (Dense)             (None, 5)                 45
#
#  batch_normalization_6 (Bat  (None, 5)                 20
#  chNormalization)
#
#  softmax_1 (Softmax)         (None, 5)                 0
#
# =================================================================
# Total params: 625 (2.44 KB)
# Trainable params: 575 (2.25 KB)
# Non-trainable params: 50 (200.00 Byte)
# _________________________________________________________________
# 21/21 [==============================] - 4s 25ms/step - loss: 1.8088 - accuracy: 0.2538 - val_loss: 1.6114 - val_accuracy: 0.2389
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/engine/training.py:3098: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native TF-Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py:854: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# RAM: 20480,	 Flash: 5368,	 MACC: 450089
#
# Epoch 1/99
# 18/21 [========================>.....] - ETA: 0s - loss: 1.5734 - accuracy: 0.3281
# Epoch 1: val_accuracy improved from -inf to 0.22343, saving model to /content/trained_models/k_4_c_1.h5
# 21/21 [==============================] - 0s 14ms/step - loss: 1.5694 - accuracy: 0.3278 - val_loss: 1.6104 - val_accuracy: 0.2234
# Epoch 2/99
# 13/21 [=================>............] - ETA: 0s - loss: 1.4587 - accuracy: 0.3810
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/engine/training.py:3098: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native TF-Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 19/21 [==========================>...] - ETA: 0s - loss: 1.4609 - accuracy: 0.3845
# Epoch 2: val_accuracy did not improve from 0.22343
# 21/21 [==============================] - 0s 11ms/step - loss: 1.4582 - accuracy: 0.3854 - val_loss: 1.6090 - val_accuracy: 0.1962
# Epoch 3/99
# 15/21 [====================>.........] - ETA: 0s - loss: 1.3754 - accuracy: 0.4406
# Epoch 3: val_accuracy improved from 0.22343 to 0.22979, saving model to /content/trained_models/k_4_c_1.h5
# 21/21 [==============================] - 0s 13ms/step - loss: 1.3845 - accuracy: 0.4371 - val_loss: 1.5925 - val_accuracy: 0.2298
# Epoch 4/99
# 15/21 [====================>.........] - ETA: 0s - loss: 1.3421 - accuracy: 0.4526
# Epoch 4: val_accuracy improved from 0.22979 to 0.28610, saving model to /content/trained_models/k_4_c_1.h5
# 21/21 [==============================] - 0s 12ms/step - loss: 1.3501 - accuracy: 0.4508 - val_loss: 1.5738 - val_accuracy: 0.2861
# Epoch 5/99
# 16/21 [=====================>........] - ETA: 0s - loss: 1.3178 - accuracy: 0.4609
# Epoch 5: val_accuracy improved from 0.28610 to 0.29155, saving model to /content/trained_models/k_4_c_1.h5
# 21/21 [==============================] - 0s 17ms/step - loss: 1.3231 - accuracy: 0.4609 - val_loss: 1.5628 - val_accuracy: 0.2916
# Epoch 6/99
# 17/21 [=======================>......] - ETA: 0s - loss: 1.3054 - accuracy: 0.4743
# Epoch 6: val_accuracy improved from 0.29155 to 0.29973, saving model to /content/trained_models/k_4_c_1.h5
# 21/21 [==============================] - 0s 17ms/step - loss: 1.3036 - accuracy: 0.4733 - val_loss: 1.5535 - val_accuracy: 0.2997
# Epoch 7/99
# 17/21 [=======================>......] - ETA: 0s - loss: 1.2900 - accuracy: 0.4761
# Epoch 7: val_accuracy improved from 0.29973 to 0.31063, saving model to /content/trained_models/k_4_c_1.h5
# 21/21 [==============================] - 0s 17ms/step - loss: 1.2873 - accuracy: 0.4749 - val_loss: 1.5438 - val_accuracy: 0.3106
# Epoch 8/99
# 20/21 [===========================>..] - ETA: 0s - loss: 1.2694 - accuracy: 0.4816
# Epoch 8: val_accuracy improved from 0.31063 to 0.31335, saving model to /content/trained_models/k_4_c_1.h5
# 21/21 [==============================] - 0s 18ms/step - loss: 1.2684 - accuracy: 0.4819 - val_loss: 1.5388 - val_accuracy: 0.3134
# Epoch 9/99
# 17/21 [=======================>......] - ETA: 0s - loss: 1.2524 - accuracy: 0.4982
# Epoch 9: val_accuracy improved from 0.31335 to 0.31698, saving model to /content/trained_models/k_4_c_1.h5
# 21/21 [==============================] - 0s 15ms/step - loss: 1.2522 - accuracy: 0.4963 - val_loss: 1.5365 - val_accuracy: 0.3170
# Epoch 10/99
# 19/21 [==========================>...] - ETA: 0s - loss: 1.2378 - accuracy: 0.5041
# Epoch 10: val_accuracy improved from 0.31698 to 0.32879, saving model to /content/trained_models/k_4_c_1.h5
# 21/21 [==============================] - 0s 13ms/step - loss: 1.2366 - accuracy: 0.5018 - val_loss: 1.5278 - val_accuracy: 0.3288
# Epoch 11/99
# 21/21 [==============================] - ETA: 0s - loss: 1.2252 - accuracy: 0.5123
# Epoch 11: val_accuracy improved from 0.32879 to 0.32970, saving model to /content/trained_models/k_4_c_1.h5
# 21/21 [==============================] - 0s 13ms/step - loss: 1.2252 - accuracy: 0.5123 - val_loss: 1.5344 - val_accuracy: 0.3297
# Epoch 12/99
# 19/21 [==========================>...] - ETA: 0s - loss: 1.2122 - accuracy: 0.5173
# Epoch 12: val_accuracy improved from 0.32970 to 0.34968, saving model to /content/trained_models/k_4_c_1.h5
# 21/21 [==============================] - 0s 13ms/step - loss: 1.2103 - accuracy: 0.5193 - val_loss: 1.5178 - val_accuracy: 0.3497
# Epoch 13/99
# 15/21 [====================>.........] - ETA: 0s - loss: 1.1976 - accuracy: 0.5167
# Epoch 13: val_accuracy improved from 0.34968 to 0.38965, saving model to /content/trained_models/k_4_c_1.h5
# 21/21 [==============================] - 0s 13ms/step - loss: 1.1992 - accuracy: 0.5224 - val_loss: 1.4781 - val_accuracy: 0.3896
# Epoch 14/99
# 15/21 [====================>.........] - ETA: 0s - loss: 1.1898 - accuracy: 0.5208
# Epoch 14: val_accuracy did not improve from 0.38965
# 21/21 [==============================] - 0s 9ms/step - loss: 1.1903 - accuracy: 0.5255 - val_loss: 1.4928 - val_accuracy: 0.3806
# Epoch 15/99
# 21/21 [==============================] - ETA: 0s - loss: 1.1808 - accuracy: 0.5267
# Epoch 15: val_accuracy improved from 0.38965 to 0.39510, saving model to /content/trained_models/k_4_c_1.h5
# 21/21 [==============================] - 0s 13ms/step - loss: 1.1808 - accuracy: 0.5267 - val_loss: 1.4612 - val_accuracy: 0.3951
# Epoch 16/99
# 21/21 [==============================] - ETA: 0s - loss: 1.1726 - accuracy: 0.5344
# Epoch 16: val_accuracy improved from 0.39510 to 0.40690, saving model to /content/trained_models/k_4_c_1.h5
# 21/21 [==============================] - 0s 13ms/step - loss: 1.1726 - accuracy: 0.5344 - val_loss: 1.4506 - val_accuracy: 0.4069
# Epoch 17/99
# 15/21 [====================>.........] - ETA: 0s - loss: 1.1644 - accuracy: 0.5333
# Epoch 17: val_accuracy did not improve from 0.40690
# 21/21 [==============================] - 0s 9ms/step - loss: 1.1651 - accuracy: 0.5383 - val_loss: 1.4584 - val_accuracy: 0.4024
# Epoch 18/99
# 17/21 [=======================>......] - ETA: 0s - loss: 1.1601 - accuracy: 0.5409
# Epoch 18: val_accuracy did not improve from 0.40690
# 21/21 [==============================] - 0s 9ms/step - loss: 1.1563 - accuracy: 0.5450 - val_loss: 1.4774 - val_accuracy: 0.4024
# Epoch 19/99
# 15/21 [====================>.........] - ETA: 0s - loss: 1.1483 - accuracy: 0.5417
# Epoch 19: val_accuracy improved from 0.40690 to 0.42507, saving model to /content/trained_models/k_4_c_1.h5
# 21/21 [==============================] - 0s 12ms/step - loss: 1.1495 - accuracy: 0.5465 - val_loss: 1.4262 - val_accuracy: 0.4251
# Epoch 20/99
# 21/21 [==============================] - ETA: 0s - loss: 1.1447 - accuracy: 0.5469
# Epoch 20: val_accuracy did not improve from 0.42507
# 21/21 [==============================] - 0s 10ms/step - loss: 1.1447 - accuracy: 0.5469 - val_loss: 1.4578 - val_accuracy: 0.4142
# Epoch 21/99
# 15/21 [====================>.........] - ETA: 0s - loss: 1.1365 - accuracy: 0.5401
# Epoch 21: val_accuracy improved from 0.42507 to 0.43143, saving model to /content/trained_models/k_4_c_1.h5
# 21/21 [==============================] - 0s 14ms/step - loss: 1.1371 - accuracy: 0.5461 - val_loss: 1.4342 - val_accuracy: 0.4314
# Epoch 22/99
# 15/21 [====================>.........] - ETA: 0s - loss: 1.1289 - accuracy: 0.5479
# Epoch 22: val_accuracy improved from 0.43143 to 0.43324, saving model to /content/trained_models/k_4_c_1.h5
# 21/21 [==============================] - 0s 12ms/step - loss: 1.1307 - accuracy: 0.5535 - val_loss: 1.4440 - val_accuracy: 0.4332
# Epoch 23/99
# 15/21 [====================>.........] - ETA: 0s - loss: 1.1236 - accuracy: 0.5500
# Epoch 23: val_accuracy improved from 0.43324 to 0.45232, saving model to /content/trained_models/k_4_c_1.h5
# 21/21 [==============================] - 0s 12ms/step - loss: 1.1253 - accuracy: 0.5578 - val_loss: 1.4093 - val_accuracy: 0.4523
# Epoch 24/99
# 15/21 [====================>.........] - ETA: 0s - loss: 1.1171 - accuracy: 0.5562
# Epoch 24: val_accuracy improved from 0.45232 to 0.45777, saving model to /content/trained_models/k_4_c_1.h5
# 21/21 [==============================] - 0s 13ms/step - loss: 1.1192 - accuracy: 0.5617 - val_loss: 1.3969 - val_accuracy: 0.4578
# Epoch 25/99
# 15/21 [====================>.........] - ETA: 0s - loss: 1.1112 - accuracy: 0.5630
# Epoch 25: val_accuracy improved from 0.45777 to 0.46866, saving model to /content/trained_models/k_4_c_1.h5
# 21/21 [==============================] - 0s 12ms/step - loss: 1.1129 - accuracy: 0.5664 - val_loss: 1.3872 - val_accuracy: 0.4687
# Epoch 26/99
# 16/21 [=====================>........] - ETA: 0s - loss: 1.1061 - accuracy: 0.5649
# Epoch 26: val_accuracy did not improve from 0.46866
# 21/21 [==============================] - 0s 9ms/step - loss: 1.1073 - accuracy: 0.5664 - val_loss: 1.3864 - val_accuracy: 0.4687
# Epoch 27/99
# 15/21 [====================>.........] - ETA: 0s - loss: 1.1000 - accuracy: 0.5724
# Epoch 27: val_accuracy improved from 0.46866 to 0.47502, saving model to /content/trained_models/k_4_c_1.h5
# 21/21 [==============================] - 0s 12ms/step - loss: 1.1021 - accuracy: 0.5738 - val_loss: 1.3787 - val_accuracy: 0.4750
# Epoch 28/99
# 15/21 [====================>.........] - ETA: 0s - loss: 1.0957 - accuracy: 0.5734
# Epoch 28: val_accuracy improved from 0.47502 to 0.48229, saving model to /content/trained_models/k_4_c_1.h5
# 21/21 [==============================] - 0s 12ms/step - loss: 1.0973 - accuracy: 0.5753 - val_loss: 1.3653 - val_accuracy: 0.4823
# Epoch 29/99
# ...
# Epoch 55/99
# 15/21 [====================>.........] - ETA: 0s - loss: 0.4864 - accuracy: 0.8422
# Epoch 55: val_accuracy did not improve from 0.63306
# 21/21 [==============================] - 0s 10ms/step - loss: 0.4972 - accuracy: 0.8357 - val_loss: 1.2158 - val_accuracy: 0.5731
# Epoch 56/99
# 21/21 [==============================] - ETA: 0s - loss: 0.5045 - accuracy: 0.8283
# Epoch 56: val_accuracy did not improve from 0.63306
# 21/21 [==============================] - 0s 11ms/step - loss: 0.5045 - accuracy: 0.8283 - val_loss: 1.4589 - val_accuracy: 0.4768
# Epoch 57/99
# 20/21 [===========================>..] - ETA: 0s - loss: 0.5127 - accuracy: 0.8246
# Epoch 57: val_accuracy did not improve from 0.63306
# 21/21 [==============================] - 0s 11ms/step - loss: 0.5114 - accuracy: 0.8252 - val_loss: 1.4810 - val_accuracy: 0.4696
# Epoch 58/99
# 21/21 [==============================] - ETA: 0s - loss: 0.5004 - accuracy: 0.8330
# Epoch 58: val_accuracy did not improve from 0.63306
# 21/21 [==============================] - 0s 10ms/step - loss: 0.5004 - accuracy: 0.8330 - val_loss: 1.5912 - val_accuracy: 0.4723
# Epoch 59/99
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5080 - accuracy: 0.8322
# Epoch 59: val_accuracy did not improve from 0.63306
# 21/21 [==============================] - 0s 11ms/step - loss: 0.5033 - accuracy: 0.8334 - val_loss: 1.6254 - val_accuracy: 0.4741
# Epoch 60/99
# 21/21 [==============================] - ETA: 0s - loss: 0.4922 - accuracy: 0.8396
# Epoch 60: val_accuracy did not improve from 0.63306
# 21/21 [==============================] - 0s 11ms/step - loss: 0.4922 - accuracy: 0.8396 - val_loss: 1.5414 - val_accuracy: 0.4877
# Epoch 61/99
# 18/21 [========================>.....] - ETA: 0s - loss: 0.4815 - accuracy: 0.8420
# Epoch 61: val_accuracy did not improve from 0.63306
# 21/21 [==============================] - 0s 15ms/step - loss: 0.4774 - accuracy: 0.8443 - val_loss: 1.4900 - val_accuracy: 0.4905
# Epoch 62/99
# 21/21 [==============================] - ETA: 0s - loss: 0.4840 - accuracy: 0.8447
# Epoch 62: val_accuracy did not improve from 0.63306
# 21/21 [==============================] - 0s 14ms/step - loss: 0.4840 - accuracy: 0.8447 - val_loss: 1.4621 - val_accuracy: 0.5141
# Epoch 63/99
# 21/21 [==============================] - ETA: 0s - loss: 0.4826 - accuracy: 0.8431
# Epoch 63: val_accuracy did not improve from 0.63306
# 21/21 [==============================] - 0s 14ms/step - loss: 0.4826 - accuracy: 0.8431 - val_loss: 1.4606 - val_accuracy: 0.5386
# Epoch 64/99
# 18/21 [========================>.....] - ETA: 0s - loss: 0.4944 - accuracy: 0.8398
# Epoch 64: val_accuracy did not improve from 0.63306
# 21/21 [==============================] - 0s 16ms/step - loss: 0.4896 - accuracy: 0.8420 - val_loss: 1.6154 - val_accuracy: 0.5086
# Epoch 65/99
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5120 - accuracy: 0.8265
# Epoch 65: val_accuracy did not improve from 0.63306
# 21/21 [==============================] - 0s 15ms/step - loss: 0.5054 - accuracy: 0.8307 - val_loss: 1.8829 - val_accuracy: 0.4986
# Epoch 66/99
# 18/21 [========================>.....] - ETA: 0s - loss: 0.5183 - accuracy: 0.8212
# Epoch 66: val_accuracy did not improve from 0.63306
# 21/21 [==============================] - 0s 16ms/step - loss: 0.5095 - accuracy: 0.8252 - val_loss: 1.5773 - val_accuracy: 0.5204
# Epoch 67/99
# 18/21 [========================>.....] - ETA: 0s - loss: 0.5167 - accuracy: 0.8247
# Epoch 67: val_accuracy did not improve from 0.63306
# 21/21 [==============================] - 0s 17ms/step - loss: 0.5101 - accuracy: 0.8279 - val_loss: 1.4188 - val_accuracy: 0.5468
# Epoch 68/99
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4989 - accuracy: 0.8298
# Epoch 68: val_accuracy did not improve from 0.63306
# 21/21 [==============================] - 0s 11ms/step - loss: 0.4920 - accuracy: 0.8334 - val_loss: 1.3965 - val_accuracy: 0.5513
# Epoch 69/99
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4799 - accuracy: 0.8384
# Epoch 69: val_accuracy did not improve from 0.63306
# 21/21 [==============================] - 0s 11ms/step - loss: 0.4740 - accuracy: 0.8416 - val_loss: 1.4537 - val_accuracy: 0.5668
# Epoch 70/99
# 18/21 [========================>.....] - ETA: 0s - loss: 0.4659 - accuracy: 0.8490
# Epoch 70: val_accuracy did not improve from 0.63306
# 21/21 [==============================] - 0s 13ms/step - loss: 0.4639 - accuracy: 0.8501 - val_loss: 1.1828 - val_accuracy: 0.6294
# Epoch 71/99
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4670 - accuracy: 0.8479
# Epoch 71: val_accuracy did not improve from 0.63306
# 21/21 [==============================] - 0s 11ms/step - loss: 0.4630 - accuracy: 0.8490 - val_loss: 1.4928 - val_accuracy: 0.5840
# Epoch 72/99
# 20/21 [===========================>..] - ETA: 0s - loss: 0.4582 - accuracy: 0.8484
# Epoch 72: val_accuracy did not improve from 0.63306
# 21/21 [==============================] - 0s 11ms/step - loss: 0.4569 - accuracy: 0.8490 - val_loss: 1.2895 - val_accuracy: 0.6031
# Epoch 73/99
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4452 - accuracy: 0.8561
# Epoch 73: val_accuracy did not improve from 0.63306
# 21/21 [==============================] - 0s 11ms/step - loss: 0.4396 - accuracy: 0.8583 - val_loss: 1.2352 - val_accuracy: 0.5922
# Epoch 74/99
# 21/21 [==============================] - ETA: 0s - loss: 0.4233 - accuracy: 0.8696
# Epoch 74: val_accuracy did not improve from 0.63306
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4233 - accuracy: 0.8696 - val_loss: 1.2537 - val_accuracy: 0.5795
# Epoch 75/99
# 21/21 [==============================] - ETA: 0s - loss: 0.4155 - accuracy: 0.8758
# Epoch 75: val_accuracy did not improve from 0.63306
# 21/21 [==============================] - 1s 26ms/step - loss: 0.4155 - accuracy: 0.8758 - val_loss: 1.3588 - val_accuracy: 0.5568
# Epoch 76/99
# 21/21 [==============================] - ETA: 0s - loss: 0.4073 - accuracy: 0.8774
# Epoch 76: val_accuracy did not improve from 0.63306
# 21/21 [==============================] - 1s 25ms/step - loss: 0.4073 - accuracy: 0.8774 - val_loss: 1.4060 - val_accuracy: 0.5586
# Epoch 77/99
# 21/21 [==============================] - ETA: 0s - loss: 0.4019 - accuracy: 0.8786
# Epoch 77: val_accuracy did not improve from 0.63306
# 21/21 [==============================] - 1s 34ms/step - loss: 0.4019 - accuracy: 0.8786 - val_loss: 1.3297 - val_accuracy: 0.5658
# Epoch 78/99
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4015 - accuracy: 0.8812
# Epoch 78: val_accuracy did not improve from 0.63306
# 21/21 [==============================] - 1s 29ms/step - loss: 0.3962 - accuracy: 0.8832 - val_loss: 1.3219 - val_accuracy: 0.5767
# Epoch 79/99
# 18/21 [========================>.....] - ETA: 0s - loss: 0.3901 - accuracy: 0.8876
# Epoch 79: val_accuracy did not improve from 0.63306
# 21/21 [==============================] - 1s 25ms/step - loss: 0.
[==============================] - ETA: 0s - loss: 0.2849 - accuracy: 0.9338
# Epoch 98: val_accuracy did not improve from 0.63306
# 21/21 [==============================] - 0s 24ms/step - loss: 0.2849 - accuracy: 0.9338 - val_loss: 1.3718 - val_accuracy: 0.5922
# Epoch 99/99
# 19/21 [==========================>...] - ETA: 0s - loss: 0.2932 - accuracy: 0.9243
# Epoch 99: val_accuracy did not improve from 0.63306
# 21/21 [==============================] - 1s 26ms/step - loss: 0.2916 - accuracy: 0.9257 - val_loss: 1.5122 - val_accuracy: 0.5758
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py:854: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# {'k': 8, 'c': 2, 'RAM': 31232, 'Flash': 12608, 'MACC': 1758265, 'max_val_acc': np.float64(0.633)}
#
#
#
#
# k_16_c_0
#
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 50, 50, 3)]       0
#
#  conv2d_16 (Conv2D)          (None, 50, 50, 16)        448
#
#  batch_normalization_30 (Ba  (None, 50, 50, 16)        64
#  tchNormalization)
#
#  re_lu_23 (ReLU)             (None, 50, 50, 16)        0
#
#  global_average_pooling2d_7  (None, 16)                0
#   (GlobalAveragePooling2D)
#
#  dense_14 (Dense)            (None, 16)                272
#
#  batch_normalization_31 (Ba  (None, 16)                64
#  tchNormalization)
#
#  re_lu_24 (ReLU)             (None, 16)                0
#
#  dense_15 (Dense)            (None, 5)                 85
#
#  batch_normalization_32 (Ba  (None, 5)                 20
#  tchNormalization)
#
#  softmax_7 (Softmax)         (None, 5)                 0
#
# =================================================================
# Total params: 953 (3.72 KB)
# Trainable params: 879 (3.43 KB)
# Non-trainable params: 74 (296.00 Byte)
# _________________________________________________________________
# 21/21 [==============================] - 4s 23ms/step - loss: 1.8337 - accuracy: 0.2086 - val_loss: 2.3082 - val_accuracy: 0.1753
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/engine/training.py:3098: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native TF-Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py:854: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# RAM: 50176,	 Flash: 5192,	 MACC: 1080281
#
#
#
#
# {'k': 16, 'c': 0, 'RAM': 'Outside the upper bound', 'Flash': 5192, 'MACC': 1080281, 'max_val_acc': -3}
#
#
#
#
# Resulting architecture: {'k': 8, 'c': 1, 'RAM': 30720, 'Flash': 7144, 'MACC': 1260281, 'max_val_acc': np.float64(0.637)}
#
# Elapsed time (search): 0:04:49.565252

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ###Test the obtained model

# %% [markdown]
# a useful function for testing 'tflite' models

# %%
def test_tflite_model(path_to_resulting_model, test_ds) :
    interpreter = tf.lite.Interpreter(str(path_to_resulting_model))
    interpreter.allocate_tensors()

    output = interpreter.get_output_details()[0]  # Model has single output.
    input = interpreter.get_input_details()[0]  # Model has single input.

    correct = 0
    wrong = 0

    for i in test_ds :
        image, label = i[0], i[1]
        # Check if the input type is quantized, then rescale input data to uint8
        if input['dtype'] == tf.uint8:
            input_scale, input_zero_point = input["quantization"]
            image = image / input_scale + input_zero_point
        input_data = tf.dtypes.cast(image, tf.uint8)
        interpreter.set_tensor(input['index'], input_data)
        interpreter.invoke()
        if label.numpy().argmax() == interpreter.get_tensor(output['index']).argmax() :
            correct = correct + 1
        else :
            wrong = wrong + 1
    print(f"\nTflite model test accuracy: {correct/(correct+wrong)}")

# %% [markdown]
# download a new image, not used in training

# %%
sunflower_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/592px-Red_sunflower.jpg"
sunflower_path = tf.keras.utils.get_file('Red_sunflower', origin=sunflower_url)

img = tf.keras.utils.load_img(
    sunflower_path, target_size=input_shape[0:2]
)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/592px-Red_sunflower.jpg
# 117948/117948 [==============================] - 0s 2us/step

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=50x50>

# %% [markdown]
# build a dataset containing the new image

# %%
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

img_label = tf.constant([[0., 0., 0., 1., 0.]]) #sunflower

test_ds = tf.data.Dataset.from_tensor_slices((img_array, img_label))
test_ds = test_ds.batch(1)

# %% [markdown]
# test the obtained model

# %%
test_tflite_model(path_to_tflite_model, test_ds)
# Out:
# Tflite model test accuracy: 1.0
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
