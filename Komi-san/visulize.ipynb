# %%
import json
import matplotlib.pyplot as plt
import pickle

# %%
with open(r'C:\Hemoglobin\project\TinyML-NAS\Experiments\Test_vanilla\search_output.json', 'r') as f:
    results = json.load(f)

# %%
plt.plot(results['iterations_accuracy'])
plt.show()

# %%
print(results["time"])
print(max(results['iterations_accuracy']))
print(results["best_architecture"])
print(results["model_architecture"])
# Out:
# 0:05:21.011231
# 0.647
# {'k': 4, 'c': 2}
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_3 (InputLayer)        [(None, 50, 50, 3)]       0
#
#  conv2d_3 (Conv2D)           (None, 50, 50, 4)         112
#
#  batch_normalization_7 (Batc  (None, 50, 50, 4)        16
#  hNormalization)
#
#  re_lu_5 (ReLU)              (None, 50, 50, 4)         0
#
#  max_pooling2d_1 (MaxPooling  (None, 25, 25, 4)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 25, 25, 8)         296
#
#  batch_normalization_8 (Batc  (None, 25, 25, 8)        32
#  hNormalization)
#
#  re_lu_6 (ReLU)              (None, 25, 25, 8)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 12, 12, 8)        0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 12)        876
#
#  batch_normalization_9 (Batc  (None, 12, 12, 12)       48
#  hNormalization)
#
# ...

# %%
with open("C:\Hemoglobin\project\TinyML-NAS\Experiments\Test_PSO\search_output.pkl", "rb") as f:
    search_output = pickle.load(f)

plt.plot(search_output['iterations_accuracy'])
plt.show()

# %%
print(search_output["time"])
print(max(search_output['iterations_accuracy']))
print(search_output["best_architecture"])
print(search_output["model_architecture"])
# Out:
# 0:17:32.531281
# 0.699
# {'k': 9, 'c': 2}
# Model: "model_34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_35 (InputLayer)       [(None, 50, 50, 3)]       0
#
#  conv2d_108 (Conv2D)         (None, 50, 50, 9)         252
#
#  batch_normalization_108 (Ba  (None, 50, 50, 9)        36
#  tchNormalization)
#
#  re_lu_108 (ReLU)            (None, 50, 50, 9)         0
#
#  max_pooling2d_74 (MaxPoolin  (None, 25, 25, 9)        0
#  g2D)
#
#  conv2d_109 (Conv2D)         (None, 25, 25, 18)        1476
#
#  batch_normalization_109 (Ba  (None, 25, 25, 18)       72
#  tchNormalization)
#
#  re_lu_109 (ReLU)            (None, 25, 25, 18)        0
#
#  max_pooling2d_75 (MaxPoolin  (None, 12, 12, 18)       0
#  g2D)
#
#  conv2d_110 (Conv2D)         (None, 12, 12, 27)        4401
#
#  batch_normalization_110 (Ba  (None, 12, 12, 27)       108
#  tchNormalization)
#
# ...

# %%
with open("C:\Hemoglobin\project\TinyML-NAS\Experiments\Test_PSO_full_cov\search_output.pkl", "rb") as f:
    search_output = pickle.load(f)

plt.plot(search_output['iterations_accuracy'])
plt.show()

# %%
print(search_output["time"])
print(max(search_output['iterations_accuracy']))
print(search_output["best_architecture"])
print(search_output["model_architecture"])
# Out:
# 0:21:57.187348
# 0.68
# {'k': 6, 'c': 2}
# Model: "model_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_17 (InputLayer)       [(None, 50, 50, 3)]       0
#
#  conv2d_63 (Conv2D)          (None, 50, 50, 6)         168
#
#  batch_normalization_47 (Bat  (None, 50, 50, 6)        24
#  chNormalization)
#
#  re_lu_63 (ReLU)             (None, 50, 50, 6)         0
#
#  max_pooling2d_31 (MaxPoolin  (None, 25, 25, 6)        0
#  g2D)
#
#  conv2d_64 (Conv2D)          (None, 25, 25, 12)        660
#
#  batch_normalization_48 (Bat  (None, 25, 25, 12)       48
#  chNormalization)
#
#  re_lu_64 (ReLU)             (None, 25, 25, 12)        0
#
#  max_pooling2d_32 (MaxPoolin  (None, 12, 12, 12)       0
#  g2D)
#
#  conv2d_65 (Conv2D)          (None, 12, 12, 18)        1962
#
#  batch_normalization_49 (Bat  (None, 12, 12, 18)       72
#  chNormalization)
#
# ...

# %%
with open(r"../Experiments/Test_PSO_full_cov_particle_10_iter_20/search_output.pkl", "rb") as f:
    search_output = pickle.load(f)

plt.plot(search_output['iterations_accuracy'])
plt.show()

# %%
print(search_output["time"])
print(max(search_output['iterations_accuracy']))
print(search_output["best_architecture"])
print(search_output["model_architecture"])
# Out:
# 0:23:48.382406
# 0.684
# {'k': 7, 'c': 3}
# Model: "model_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_11 (InputLayer)       [(None, 50, 50, 3)]       0
#
#  conv2d_52 (Conv2D)          (None, 50, 50, 7)         196
#
#  batch_normalization_42 (Bat  (None, 50, 50, 7)        28
#  chNormalization)
#
#  re_lu_52 (ReLU)             (None, 50, 50, 7)         0
#
#  max_pooling2d_32 (MaxPoolin  (None, 25, 25, 7)        0
#  g2D)
#
#  conv2d_53 (Conv2D)          (None, 25, 25, 14)        896
#
#  batch_normalization_43 (Bat  (None, 25, 25, 14)       56
#  chNormalization)
#
#  re_lu_53 (ReLU)             (None, 25, 25, 14)        0
#
#  max_pooling2d_33 (MaxPoolin  (None, 12, 12, 14)       0
#  g2D)
#
#  conv2d_54 (Conv2D)          (None, 12, 12, 21)        2667
#
#  batch_normalization_44 (Bat  (None, 12, 12, 21)       84
#  chNormalization)
#
# ...

# %%
with open(r"../Experiments\vanillaNAS\search_output.pkl", "rb") as f:
    search_output = pickle.load(f)

plt.plot(search_output['iterations_accuracy'])
plt.show()

# %%
print(search_output["time"])
print(max(search_output['iterations_accuracy']))
print(search_output["best_architecture"])
print(search_output["model_architecture"])
# Out:
# 0:04:04.951284
# 0.659
# {'k': 8, 'c': 2}
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_7 (InputLayer)        [(None, 50, 50, 3)]       0
#
#  conv2d_13 (Conv2D)          (None, 50, 50, 8)         224
#
#  batch_normalization_25 (Bat  (None, 50, 50, 8)        32
#  chNormalization)
#
#  re_lu_19 (ReLU)             (None, 50, 50, 8)         0
#
#  max_pooling2d_7 (MaxPooling  (None, 25, 25, 8)        0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 25, 25, 16)        1168
#
#  batch_normalization_26 (Bat  (None, 25, 25, 16)       64
#  chNormalization)
#
#  re_lu_20 (ReLU)             (None, 25, 25, 16)        0
#
#  max_pooling2d_8 (MaxPooling  (None, 12, 12, 16)       0
#  2D)
#
#  conv2d_15 (Conv2D)          (None, 12, 12, 24)        3480
#
#  batch_normalization_27 (Bat  (None, 12, 12, 24)       96
#  chNormalization)
#
# ...

# %%
plt.plot(search_output['train_losses'])
plt.plot(search_output['val_losses'])

plt.show()

# %%
with open(r"../Experiments\vanillaNAS_CNN\search_output.pkl", "rb") as f:
    search_output = pickle.load(f)

plt.plot(search_output['iterations_accuracy'])
plt.show()

# %%
print(search_output["time"])
print(max(search_output['iterations_accuracy']))
print(search_output["best_architecture"])
print(search_output["model_architecture"])
# Out:
# 0:03:20.861579
# 0.684
# {'k': 8, 'c': 2}
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_7 (InputLayer)        [(None, 50, 50, 3)]       0
#
#  conv2d_19 (Conv2D)          (None, 50, 50, 8)         224
#
#  batch_normalization_13 (Bat  (None, 50, 50, 8)        32
#  chNormalization)
#
#  re_lu_19 (ReLU)             (None, 50, 50, 8)         0
#
#  max_pooling2d_7 (MaxPooling  (None, 25, 25, 8)        0
#  2D)
#
#  conv2d_20 (Conv2D)          (None, 25, 25, 16)        1168
#
#  batch_normalization_14 (Bat  (None, 25, 25, 16)       64
#  chNormalization)
#
#  re_lu_20 (ReLU)             (None, 25, 25, 16)        0
#
#  max_pooling2d_8 (MaxPooling  (None, 12, 12, 16)       0
#  2D)
#
#  conv2d_21 (Conv2D)          (None, 12, 12, 24)        3480
#
#  batch_normalization_15 (Bat  (None, 12, 12, 24)       96
#  chNormalization)
#
# ...

# %%
plt.plot(search_output['train_losses'])
plt.plot(search_output['val_losses'])

plt.show()

# %%
with open(r"../Experiments\vanillaNAS_CNNv2\search_output.pkl", "rb") as f:
    search_output = pickle.load(f)

plt.plot(search_output['iterations_accuracy'])
plt.show()

# %%
print(search_output["time"])
print(max(search_output['iterations_accuracy']))
print(search_output["best_architecture"])
print(search_output["model_architecture"])
# Out:
# 0:04:48.771562
# 0.688
# {'k': 4, 'c': 2}
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_3 (InputLayer)        [(None, 50, 50, 3)]       0
#
#  conv2d_5 (Conv2D)           (None, 50, 50, 4)         112
#
#  batch_normalization_3 (Batc  (None, 50, 50, 4)        16
#  hNormalization)
#
#  re_lu_3 (ReLU)              (None, 50, 50, 4)         0
#
#  max_pooling2d_1 (MaxPooling  (None, 25, 25, 4)        0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 25, 25, 8)         296
#
#  batch_normalization_4 (Batc  (None, 25, 25, 8)        32
#  hNormalization)
#
#  re_lu_4 (ReLU)              (None, 25, 25, 8)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 12, 12, 8)        0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 12, 12, 12)        876
#
#  batch_normalization_5 (Batc  (None, 12, 12, 12)       48
#  hNormalization)
#
# ...

# %%
plt.plot(search_output['train_losses'])
plt.plot(search_output['val_losses'])

plt.show()
